# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260910/blob/main/tibame20260917_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1
# hello
# hello
# hello
# 2
# hello
for i in range(2):
    print(i+1)
    for j in range(3):
        print("hello")

# %%
def print3():
    for j in range(3):
        print("hello")

for i in range(2):
    print(i+1)
    print3()
# Out:
# 1
# hello
# hello
# hello
# 2
# hello
# hello
# hello

# %%
# oxoxo
# xoxox
# oxoxo
# xoxox
for i in range(4):
    line = ""
    for j in range(5):
        if  (j + i) % 2 == 0:
            line = line + "o"
        else:
            line = line + "x"
    print(line)
# Out:
# oxoxo
# xoxox
# oxoxo
# xoxox
